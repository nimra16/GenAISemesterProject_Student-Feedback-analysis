# %% [markdown]
# # Task2:  LLM Model

# %%
import os
import pandas as pd
# from google import genai
import time
import ollama
from ollama import chat
from ollama import ChatResponse

import pandas as pd

# %% [markdown]
# # Feedback data

# %%
# Load Dataset
df = pd.read_csv("Datasets/dummyFeedbackdataWithclasses.csv")  # Ensure the dataset has 'text' and 'label' columns
print(len(df))
# Preprocessing
def preprocess_data(text):
    return text.lower().strip()

# Check for null values in the DataFrame
null_values = df.isnull().sum()

# Print the columns with null values
print(null_values[null_values > 0])
#remove null values    
df = df.dropna(subset=['Comments'])
print(len(df))
# Out:
# 2920
# Comments                        23
# llm_response                  2910
# Teaching Pedagogy_terms       2914
# Teaching Pedagogy_polarity    2914
# Knowledge_terms               2916
# Knowledge_polarity            2916
# Experience_terms              2919
# Experience_polarity           2919
# dtype: int64
# 2897

# %%
# Filter rows where the 'Comments' column contains only a single word
single_word_data = df[df['Comments'].str.split().str.len() == 1]
print(len(single_word_data))
# Display the filtered data
single_word_data.head(20)
# Out:
# 847
#       FacultyName                        Course       Comments   Target  \
# 0   NIMRA MUGHAL   Programming Fundamentals(Pr)              .  Teacher
# 2   NIMRA MUGHAL   Programming Fundamentals(Pr)        bestttt   Course
# 3   NIMRA MUGHAL   Programming Fundamentals(Pr)           best   Course
# 5   NIMRA MUGHAL   Programming Fundamentals(Pr)           Good   Course
# 6   NIMRA MUGHAL   Programming Fundamentals(Pr)           hard   Course
# 19  NIMRA MUGHAL   Programming Fundamentals(Pr)    Informative   Course
# 24  NIMRA MUGHAL   Programming Fundamentals(Pr)  Knowledgeable   Course
# 26  NIMRA MUGHAL   Programming Fundamentals(Pr)   knowledgable   Course
# 27  NIMRA MUGHAL   Programming Fundamentals(Pr)           good   Course
# 30  NIMRA MUGHAL   Programming Fundamentals(Pr)           good   Course
# 37  NIMRA MUGHAL   Programming Fundamentals(Pr)      Excellent   Course
# 38  NIMRA MUGHAL   Programming Fundamentals(Pr)           Good   Course
# 44  NIMRA MUGHAL   Programming Fundamentals(Pr)           Good  Teacher
# 58  NIMRA MUGHAL   Programming Fundamentals(Pr)    cooperative  Teacher
# 67  NIMRA MUGHAL   Programming Fundamentals(Pr)           good  Teacher
# 77  NIMRA MUGHAL   Programming Fundamentals(Pr)          Good.  Teacher
# 79  NIMRA MUGHAL   Programming Fundamentals(Pr)              .   Course
# 80  NIMRA MUGHAL   Programming Fundamentals(Pr)           Nice   Course
# 82  NIMRA MUGHAL   Programming Fundamentals(Pr)              .   Course
# 83  NIMRA MUGHAL   Programming Fundamentals(Pr)              .   Course
#
#       Class llm_response Teaching Pedagogy_terms Teaching Pedagogy_polarity  \
# 0   Class 1          NaN                     NaN                        NaN
# 2   Class 1          NaN                     NaN                        NaN
# 3   Class 1          NaN                     NaN                        NaN
# 5   Class 1          NaN                     NaN                        NaN
# 6   Class 1          NaN                     NaN                        NaN
# 19  Class 1          NaN                     NaN                        NaN
# 24  Class 1          NaN                     NaN                        NaN
# 26  Class 1          NaN                     NaN                        NaN
# 27  Class 1          NaN                     NaN                        NaN
# 30  Class 2          NaN                     NaN                        NaN
# 37  Class 2          NaN                     NaN                        NaN
# 38  Class 2          NaN                     NaN                        NaN
# 44  Class 2          NaN                     NaN                        NaN
# 58  Class 2          NaN                     NaN                        NaN
# 67  Class 3          NaN                     NaN                        NaN
# 77  Class 3          NaN                     NaN                        NaN
# 79  Class 3          NaN                     NaN                        NaN
# 80  Class 3          NaN                     NaN                        NaN
# 82  Class 3          NaN                     NaN                        NaN
# 83  Class 3          NaN                     NaN                        NaN
#
#    Knowledge_terms Knowledge_polarity Experience_terms Experience_polarity
# 0              NaN                NaN              NaN                 NaN
# 2              NaN                NaN              NaN                 NaN
# 3              NaN                NaN              NaN                 NaN
# 5              NaN                NaN              NaN                 NaN
# 6              NaN                NaN              NaN                 NaN
# 19             NaN                NaN              NaN                 NaN
# 24             NaN                NaN              NaN                 NaN
# 26             NaN                NaN              NaN                 NaN
# 27             NaN                NaN              NaN                 NaN
# 30             NaN                NaN              NaN                 NaN
# 37             NaN                NaN              NaN                 NaN
# 38             NaN                NaN              NaN                 NaN
# 44             NaN                NaN              NaN                 NaN
# 58             NaN                NaN              NaN                 NaN
# 67             NaN                NaN              NaN                 NaN
# 77             NaN                NaN              NaN                 NaN
# 79             NaN                NaN              NaN                 NaN
# 80             NaN                NaN              NaN                 NaN
# 82             NaN                NaN              NaN                 NaN
# 83             NaN                NaN              NaN                 NaN

# %%
#Remove the single_word_data from the original DataFrame
df = df[~df['Comments'].isin(single_word_data['Comments'])]
print(len(df))
# Out:
# 2050

# %% [markdown]
# ## LLM Prompt

# %%
system_prompt = """
You are an expert aspect based sentiment analysis model. Given a review about a teacher, extract relevant information based on the following aspect categories:

-Teaching Pedagogy

-Knowledge

-Fair in Assessment

-Experience

-Behavior

If the aspect has been mentioned in the review, provide:

Extracted Phrase or Evidence from Review

Polarity: One of {Positive, Negative, Neutral}

If an aspect is not mentioned, do not include it in the output.
The output should be in JSON format with the following structure:
```json
{
  "Teaching Pedagogy": {
    "Extracted Phrase": "...",
    "Polarity": "..."
  },
  "Knowledge": {
    "Extracted Phrase": "...",
    "Polarity": "..."
  },  
  "Fair in Assessment
": {
    "Extracted Phrase": "...",
    "Polarity": "..."
  },
...
}

If any of the aspects are not mentioned in the review, do not include them in the output.
"""

# %%
system_prompt = """
    You are an expert in Aspect-Based Sentiment Analysis (ABSA). Your task is to analyze teacher reviews and extract aspect-specific information based on the following predefined aspect categories:

    - Teaching Pedagogy  
    - Knowledge  
    - Fair in Assessment  
    - Experience  
    - Behavior  

    For each aspect that is **explicitly or implicitly mentioned** in the review:

    1. Identify and extract the **aspect term(s) or phrase(s)** used in the review that are related to the aspect category.
    2. Determine the **sentiment polarity** expressed toward that aspect. Choose one of: {Positive, Negative, Neutral}.

    If an aspect is not mentioned in the review, **do not include it in the output**.

    Return the output in a structured JSON format as follows:
    ```json
    {
    "Aspect Category": {
        "Aspect Terms": ["..."],
        "Extracted Phrase": "...",
        "Polarity": "..."
    },
    ...
    }
"""

# %% [markdown]
# ## Select Data sample

# %% [markdown]
# ## OLamma other models

# %%
import pandas as pd
import json

# Your existing Ollama call function
def ask_ollama(input_content, system_prompt, model_name="mistral"):
    response = ollama.chat(model=model_name, messages=[
        {'role': 'system', 'content': system_prompt},
        {'role': 'user', 'content': input_content}
    ])
    response_text = response['message']['content'].strip()
    return response_text

# %% [markdown]
# ### Mistral

# %%
# Example usage with the ask_deepseek function
input_content = "The teacher is very good in terms of knowledge and wisdom. She always prepared for teaching. She doesn't do favouritism."
response = ask_ollama(input_content, system_prompt, 'mistral')
print(type(response))
print(response)
# Out:
# <class 'str'>
# ```json
# {
#     "Knowledge": {
#         "Aspect Terms": ["knowledge", "wisdom"],
#         "Extracted Phrase": "The teacher is very good in terms of knowledge and wisdom.",
#         "Polarity": "Positive"
#     },
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["prepared for teaching"],
#         "Extracted Phrase": "She always prepared for teaching.",
#         "Polarity": "Positive"
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": ["does not do favouritism"],
#         "Extracted Phrase": "She doesn't do favouritism.",
#         "Polarity": "Positive"
#     }
# }
# ```

# %%
import json

def parse_json_safe(response_text):
    try:
        # Try to extract just the JSON part if it's embedded in extra text
        json_start = response_text.find('{')
        json_end = response_text.rfind('}') + 1
        json_substring = response_text[json_start:json_end]
        return json.loads(json_substring)
    except Exception as e:
        print(f"JSON parsing failed: {e}\nRaw response: {response_text}")
        return None

# %%
# Define aspects and related columns
aspects = ["Teaching Pedagogy", "Knowledge", "Fair in Assessment", "Experience", "Behavior"]
term_columns = [f"{aspect}_terms" for aspect in aspects]
polarity_columns = [f"{aspect}_polarity" for aspect in aspects]

# Add empty columns
for col in term_columns + polarity_columns:
    if col not in df.columns:
        df[col] = ""

# Get indices to update
indices_to_process = df[df['Target'] == 'Teacher'].index

# Initialize batch buffer
batch_records = []
batch_size = 10

# %%
model_name = 'mistral'  # Replace with your model name
for count, idx in enumerate(indices_to_process, start=1):
    feedback = df.at[idx, 'Comments']
    try:
        result_json = ask_ollama(feedback, system_prompt)
        df.at[idx, "llm_response"] = result_json  # Save raw LLM response
        
        result_dict = parse_json_safe(result_json)

        if result_dict:
            for aspect in aspects:
                if aspect in result_dict:
                    df.at[idx, f"{aspect}_terms"] = result_dict[aspect].get("Extracted Phrase", "")
                    df.at[idx, f"{aspect}_polarity"] = result_dict[aspect].get("Polarity", "")
    except Exception as e:
        print(f"Error at index {idx}: {e}")
        continue

    if count % batch_size == 0 or count == len(indices_to_process):
        df.loc[indices_to_process].to_csv("Datasets/checkpoint_feedback_" + model_name +"2.csv", index=False)
        print(f"Checkpoint saved after {count} rows.")
# Out:
# Checkpoint saved after 10 rows.
# Checkpoint saved after 20 rows.
# Error at index 62: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 143)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["teacher"],
#       "Extracted Phrase": "very good teacher",
#       "Polarity": "Positive"
#   },
# }
# ```
#
# In this example, since the review explicitly mentions the teacher and expresses a positive sentiment, only the Teaching Pedagogy aspect is included in the output. The other aspects (Knowledge, Fair in Assessment, Experience, Behavior) are not mentioned or implied in the given review, so they are not returned.
# Checkpoint saved after 30 rows.
# JSON parsing failed: Expecting ',' delimiter: line 25 column 29 (char 1013)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["effective teaching methods", "innovative lesson plans"],
#       "Extracted Phrase": "The teacher used effective teaching methods and innovative lesson plans.",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       "Aspect Terms": ["in-depth understanding", "expertise in the subject matter"],
#       "Extracted Phrase": "This teacher had an in-depth understanding and expertise in the subject matter.",
#       "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": ["fair grading policy", "objective feedback"],
#       "Extracted Phrase": "The teacher had a fair grading policy and provided objective feedback.",
#       "Polarity": "Positive"
#   },
#   "Experience": {
#       "Aspect Terms": ["wonderful learning experience"],
#       "Extracted Phrase": "I had a wonderful learning experience with this teacher.",
#       "Polarity": "Positive"
#   },
#   "Behavior": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral" // No information about behavior provided in the review
#   }
# }
# ```
# Checkpoint saved after 40 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 132)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["very"],
#       "Extracted Phrase": "very good",
#       "Polarity": "Positive"
#   },
# }
# ```
# Checkpoint saved after 50 rows.
# Checkpoint saved after 60 rows.
# Checkpoint saved after 70 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 9 (char 192)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["student centric"],
#         "Extracted Phrase": "great and cooperative",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         // Not mentioned in the review, so it will not be included.
#     },
#     "Fair in Assessment": {
#         // Not mentioned in the review, so it will not be included.
#     },
#     "Experience": {
#         // Not explicitly mentioned, but can be inferred from 'great and cooperative'. So, it will not be included unless explicitly asked for.
#     },
#     "Behavior": {
#         "Aspect Terms": ["respectful to students"],
#         "Extracted Phrase": "respectful to students",
#         "Polarity": "Positive"
#     }
# }
# ```
# Checkpoint saved after 80 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 153)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["overall"],
#     "Extracted Phrase": "good teacher",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     // Not mentioned, hence not included in the output
#   },
#   "Fair in Assessment": {
#     // Not mentioned, hence not included in the output
#   },
#   "Experience": {
#     // Not mentioned, hence not included in the output
#   },
#   "Behavior": {
#     // Not mentioned, hence not included in the output
#   }
# }
# ```
# Checkpoint saved after 90 rows.
# Checkpoint saved after 100 rows.
# JSON parsing failed: Expecting ',' delimiter: line 10 column 31 (char 316)
# Raw response: ```json
#     {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["method of teaching"],
#         "Extracted Phrase": "not good",
#         "Polarity": "Negative"
#     },
#     "Behavior": {
#         "Aspect Terms": ["showing Ads"],
#         "Extracted Phrase": "somehow he grab attention by showing Ads",
#         "Polarity": "Neutral" // The sentiment about the behavior is neutral as it seems to be a factual statement rather than an evaluation of the teacher's behavior itself.
#     }
#     }
# ```
# Checkpoint saved after 110 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 12 column 3 (char 544)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["prepared", "procrastinating", "lethargic"],
#       "Extracted Phrase": "He always used to make excuses as he was never prepared for the class. A very procrastinating and a lethargic teacher.",
#       "Polarity": "Negative"
#   },
#   "Behavior": {
#       "Aspect Terms": ["excuses", "procrastinating", "lethargic"],
#       "Extracted Phrase": "He always used to make excuses as he was never prepared for the class. A very procrastinating and a lethargic teacher.",
#       "Polarity": "Negative"
#   },
#   // No information provided about Knowledge, Fair in Assessment, or Experience, so these aspects are not included in the output.
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 20 column 27 (char 885)
# Raw response: Here's an example of how the output might look for a teacher review:
#
# ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["clear explanations", "engaging lessons"],
#     "Extracted Phrase": "provides clear explanations and engages students during lessons",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Aspect Terms": ["expertise in the subject", "extensive knowledge"],
#     "Extracted Phrase": "demonstrates expertise in the subject and has extensive knowledge of the course material",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": ["fair grading system", "considers everyone equally"],
#     "Extracted Phrase": "implements a fair grading system that considers every student equally",
#     "Polarity": "Positive"
#   },
#   "Experience": {
#     "Aspect Terms": ["years of experience", "experienced teacher"],
#     "Extracted Phrase": "is an experienced teacher with years of experience in the field",
#     "Polarity": "Neutral" (as experience itself is usually not inherently positive or negative)
#   },
#   "Behavior": {
#     "Aspect Terms": ["professionalism", "positive attitude"],
#     "Extracted Phrase": "shows great professionalism and maintains a positive attitude in the classroom",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 120 rows.
# Checkpoint saved after 130 rows.
# Error at index 331: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 9 (char 234)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["Great teaching", "always motivate"],
#         "Extracted Phrase": "Great teaching way, always motivate to learn ",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         // Since there is no explicit or implicit mention of 'Knowledge' in the review, this aspect will not be included in the output.
#     },
#     "Fair in Assessment": {
#         // Since there is no explicit or implicit mention of 'Fair in Assessment' in the review, this aspect will not be included in the output.
#     },
#     "Experience": {
#         // Since there is no explicit or implicit mention of 'Experience' in the review, this aspect will not be included in the output.
#     },
#     "Behavior": {
#         // Since there is no explicit or implicit mention of 'Behavior' in the review, this aspect will not be included in the output.
#     }
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 149)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["teaching"],
#       "Extracted Phrase": ["exceptional teaching"],
#       "Polarity": "Positive"
#   },
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 10 column 30 (char 300)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["Sir", "teach"],
#       "Extracted Phrase": "Sir is best and also know the Subject how to teach.",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       "Aspect Terms": ["Sir", "Subject"],
#       "Extracted Phrase": "",
#       "Polarity": "Positive" // Implicitly positive based on the use of 'best' and 'know'
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   },
#   "Experience": {
#       "Aspect Terms": ["sir", "recommended"],
#       "Extracted Phrase": "as a best teacher Masha Allah. sir always recommended.",
#       "Polarity": "Positive"
#   },
#   "Behavior": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   }
# }
# ```
# Checkpoint saved after 140 rows.
# JSON parsing failed: Extra data: line 28 column 1 (char 864)
# Raw response: Here are the teacher reviews along with the corresponding output in JSON format based on the given aspect categories:
#
# Review 1:
# ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["interactive", "engaging"],
#     "Extracted Phrase": "The interactive and engaging teaching methodologies really helped me to grasp difficult concepts.",
#     "Polarity": "Positive"
# },
# "Knowledge": {
#     "Aspect Terms": ["comprehensive", "deep", "thorough"],
#     "Extracted Phrase": "The teacher has a deep and comprehensive understanding of the subject matter which made learning it thoroughly enjoyable.",
#     "Polarity": "Positive"
# },
# "Fair in Assessment": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
# },
# "Experience": {
#     "Aspect Terms": ["memorable", "enlightening"],
#     "Extracted Phrase": "Overall, it was a memorable and enlightening experience.",
#     "Polarity": "Positive"
# },
# "Behavior": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
# }
# }
# ```
#
# Review 2:
# ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["dull", "boring"],
#     "Extracted Phrase": "The teacher's approach is quite dull and boring.",
#     "Polarity": "Negative"
# },
# "Knowledge": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
# },
# "Fair in Assessment": {
#     "Aspect Terms": ["strict"],
#     "Extracted Phrase": "Although the teacher is strict in assessments, I appreciate it because it helps me stay focused.",
#     "Polarity": "Positive"
# },
# "Experience": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
# },
# "Behavior": {
#     "Aspect Terms": ["unprofessional"],
#     "Extracted Phrase": "The teacher's unprofessional behavior can sometimes be distracting.",
#     "Polarity": "Negative"
# }
# }
# ```
#
# Review 3:
# ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["creative", "effective"],
#     "Extracted Phrase": "The creative teaching methods used were effective in helping me understand the subject matter better.",
#     "Polarity": "Positive"
# },
# "Knowledge": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
# },
# "Fair in Assessment": {
#     "Aspect Terms": ["objective"],
#     "Extracted Phrase": "The teacher is objective in their assessments.",
#     "Polarity": "Positive"
# },
# "Experience": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
# },
# "Behavior": {
#     "Aspect Terms": ["respectful"],
#     "Extracted Phrase": "The teacher is respectful and maintains a positive classroom environment.",
#     "Polarity": "Positive"
# }
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 15 column 32 (char 716)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["teacher", "good"],
#         "Extracted Phrase": "But I would like to say that there should be some changes like the teacher must give practical assignments to the students and also make them to how to perform such Data Science operations.",
#         "Polarity": "Negative"
#     },
#     "Experience": {
#         "Aspect Terms": ["new and emerging field", "Teacher"],
#         "Extracted Phrase": "Data Science is new and emerging field so it was also new experience Teacher to teach this course at that level.",
#         "Polarity": "Neutral"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["teacher"],
#         "Extracted Phrase": "",
#         "Polarity": "Positive" // The review implies positive knowledge, but there is no specific mention of the teacher's knowledge being insufficient or adequate.
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // No sentiment expressed towards this aspect
#     },
#     "Behavior": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // No sentiment expressed towards this aspect
#     }
# }
# ```
# Checkpoint saved after 150 rows.
# Checkpoint saved after 160 rows.
# Checkpoint saved after 170 rows.
# Checkpoint saved after 180 rows.
# Checkpoint saved after 190 rows.
# JSON parsing failed: Expecting ',' delimiter: line 20 column 30 (char 454)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "polite",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   },
#   "Experience": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "teacher",
#       "Polarity": "Positive" (since 'polite' is generally a positive trait)
#   },
#   "Behavior": {
#       "Aspect Terms": ["polite"],
#       "Extracted Phrase": "",
#       "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 200 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 141)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["good"],
#       "Extracted Phrase": "good learning time",
#       "Polarity": "Positive"
#   },
# }
# ```
# Checkpoint saved after 210 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 205)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["prepared", "class", "teach"],
#       "Extracted Phrase": "he is always prepared for class and teach in a very good way",
#       "Polarity": "Positive"
#   },
# }
# ```
# Checkpoint saved after 220 rows.
# JSON parsing failed: Extra data: line 28 column 1 (char 609)
# Raw response: 1. Review: "The teacher was very knowledgeable and always made complex concepts easy to understand. However, I felt that the assessments were a bit unfair because they didn't account for all the topics we covered."
#
# ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["made complex concepts easy to understand"],
#     "Extracted Phrase": "",
#     "Polarity": "Positive"
# },
# "Knowledge": {
#     "Aspect Terms": ["very knowledgeable"],
#     "Extracted Phrase": "",
#     "Polarity": "Positive"
# },
# "Fair in Assessment": {
#     "Aspect Terms": ["a bit unfair"],
#     "Extracted Phrase": "didn't account for all the topics we covered",
#     "Polarity": "Negative"
# },
# "Experience": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": ""
# },
# "Behavior": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": ""
# }
# }
# ```
#
# 2. Review: "I really enjoyed the teaching methods used, but I found some of the material a bit outdated."
#
# ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["teaching methods used"],
#     "Extracted Phrase": "",
#     "Polarity": "Positive"
# },
# "Knowledge": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": ""
# },
# "Fair in Assessment": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": ""
# },
# "Experience": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": ""
# },
# "Behavior": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": ""
# },
# "Teaching Pedagogy - Knowledge": {
#     "Aspect Terms": ["found some of the material a bit outdated"],
#     "Extracted Phrase": "",
#     "Polarity": "Negative"
# }
# }
# ```
# Checkpoint saved after 230 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 154)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["teaching"],
#     "Extracted Phrase": "good teacher",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     // This aspect is not explicitly or implicitly mentioned in the review, so it's not included in the output.
#   },
#   "Fair in Assessment": {
#     // This aspect is not explicitly or implicitly mentioned in the review, so it's not included in the output.
#   },
#   "Experience": {
#     // This aspect is not explicitly or implicitly mentioned in the review, so it's not included in the output.
#   },
#   "Behavior": {
#     // This aspect is not explicitly or implicitly mentioned in the review, so it's not included in the output.
#   }
# }
# ```
# In this example, the review only mentions that the teacher is good, which refers to teaching pedagogy. Since there are no negative or neutral terms or phrases in the given review, the sentiment polarity is positive. For aspects that are not mentioned, they are not included in the output as per your instructions.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 18 column 30 (char 524)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["dedicated", "adept", "simplifying lessons"],
#     "Extracted Phrase": "A dedicated educator, adept at simplifying lessons",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Aspect Terms": ["extensive knowledge base"],
#     "Extracted Phrase": "possesses an extensive knowledge base",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Experience": {
#     "Aspect Terms": ["..."], // This aspect is not explicitly mentioned, so no information can be extracted.
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Behavior": {
#     "Aspect Terms": ["exemplary behavior"],
#     "Extracted Phrase": "showcases exemplary behavior",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 240 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 7 (char 166)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["teacher"],
#       "Extracted Phrase": "very good teacher",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // Not mentioned in the review, so no output for this category.
#   },
#   "Fair in Assessment": {
#       // Not mentioned in the review, so no output for this category.
#   },
#   "Experience": {
#       // Not mentioned in the review, so no output for this category.
#   },
#   "Behavior": {
#       // Not mentioned in the review, so no output for this category.
#   }
# }
# ```
# Checkpoint saved after 250 rows.
# JSON parsing failed: Expecting ',' delimiter: line 15 column 27 (char 518)
# Raw response: Based on the given teacher review, here's the analysis for each aspect category:
#
# ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["innovative teaching methods", "interactive lessons"],
#     "Extracted Phrase": "He uses innovative teaching methods and makes the lessons interactive.",
#     "Polarity": "Positive"
# },
# "Knowledge": {
#     "Aspect Terms": ["expertise", "extensive knowledge"],
#     "Extracted Phrase": "He has extensive knowledge and expertise in the field.",
#     "Polarity": "Positive"
# },
# "Fair in Assessment": {
#     "Aspect Terms": [],
#     "Extracted Phrase": null,
#     "Polarity": "Neutral" (Since there's no explicit or implicit mention about fairness in assessment)
# },
# "Experience": {
#     "Aspect Terms": ["experienced", "seasoned"],
#     "Extracted Phrase": "He is an experienced and seasoned teacher.",
#     "Polarity": "Positive"
# },
# "Behavior": {
#     "Aspect Terms": [],
#     "Extracted Phrase": null,
#     "Polarity": "Neutral" (Since there's no explicit or implicit mention about behavior)
# }
# }
# ```
#
# In this example, the review explicitly mentions and praises the teacher for his innovative teaching methods, extensive knowledge, being experienced, and seasoned. The aspect of fairness in assessment is not mentioned, so it is marked as neutral. Similarly, there's no mention regarding the behavior of the teacher, so it is also marked as neutral.
# Checkpoint saved after 260 rows.
# Checkpoint saved after 270 rows.
# Checkpoint saved after 280 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 153)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["teaching"],
#         "Extracted Phrase": "the way teaching",
#         "Polarity": "Positive"
#     },
# }
# ```
# Checkpoint saved after 290 rows.
# Checkpoint saved after 300 rows.
# JSON parsing failed: Expecting value: line 1 column 1 (char 0)
# Raw response: Based on the review provided ("nice men"), there is no explicit or implicit mention of any predefined aspect categories (Teaching Pedagogy, Knowledge, Fair in Assessment, Experience, Behavior). Hence, no output will be generated for this particular review.
#
# For future reviews, remember to analyze sentences that may imply the aspects such as:
#
# - Teaching Pedagogy: "The professor uses innovative teaching methods." or "The teacher's lectures are too traditional."
# - Knowledge: "The instructor is knowledgeable in the subject matter." or "I found the content presented confusing."
# - Fair in Assessment: "The exams were fair and accurately assessed our understanding of the material." or "The tests were too difficult and not a true reflection of our learning."
# - Experience: "I had a great experience in this class." or "I would avoid this course if I could."
# - Behavior: "The teacher was always respectful to students." or "He often disregarded student questions during lectures."
# Checkpoint saved after 310 rows.
# Checkpoint saved after 320 rows.
# Checkpoint saved after 330 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 166)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["way of teaching"],
#       "Extracted Phrase": "Good teacher and way of teaching",
#       "Polarity": "Positive"
#   },
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 7 (char 217)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["way he teaches", "Explain"],
#       "Extracted Phrase": "the way he teaches and Explains every little thing",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // Not mentioned in the review, so not included in the output.
#   },
#   "Fair in Assessment": {
#       // Not mentioned in the review, so not included in the output.
#   },
#   "Experience": {
#       // Not mentioned in the review, so not included in the output.
#   },
#   "Behavior": {
#       // Not mentioned in the review, so not included in the output.
#   }
# }
# ```
# Checkpoint saved after 340 rows.
# Checkpoint saved after 350 rows.
# Checkpoint saved after 360 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 190)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["such a humble personality"],
#       "Extracted Phrase": "such a humble personality",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#     // No aspect term or phrase is explicitly mentioned, so the object is not included in the output.
#   },
#   "Fair in Assessment": {
#     // No aspect term or phrase is explicitly mentioned, so the object is not included in the output.
#   },
#   "Experience": {
#     // No aspect term or phrase is explicitly mentioned, so the object is not included in the output.
#   },
#   "Behavior": {
#     // No aspect term or phrase is explicitly mentioned, so the object is not included in the output.
#   }
# }
# ```
# Checkpoint saved after 370 rows.
# JSON parsing failed: Extra data: line 28 column 1 (char 1100)
# Raw response: Here is an example of how the output could look like for a review:
#
# ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["creative", "interactive"],
#         "Extracted Phrase": "The teacher uses very creative and interactive methods during lessons.",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["expertise", "deep understanding"],
#         "Extracted Phrase": "She has a deep understanding of the subject matter and is an expert in her field.",
#         "Polarity": "Positive"
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": ["objective", "consistent"],
#         "Extracted Phrase": "The teacher is objective and consistent in his assessments.",
#         "Polarity": "Positive"
#     },
#     "Experience": {
#         "Aspect Terms": ["relevant", "useful"],
#         "Extracted Phrase": "The practical experience provided by the teacher was both relevant and useful.",
#         "Polarity": "Positive"
#     },
#     "Behavior": {
#         "Aspect Terms": ["professionalism", "respect"],
#         "Extracted Phrase": "I appreciated the professionalism and respect shown by the teacher in class.",
#         "Polarity": "Positive"
#     }
# }
# ```
#
# For a negative review, the polarity would be negative for one or more aspects:
#
# ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["boring", "dull"],
#         "Extracted Phrase": "The teaching methods were boring and dull.",
#         "Polarity": "Negative"
#     },
#     ...
# }
# ```
# Checkpoint saved after 380 rows.
# JSON parsing failed: Expecting ',' delimiter: line 10 column 31 (char 303)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "1st semester accounting was among my favourite subjects",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["accounting"],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // Assuming there's no sentiment expressed towards the knowledge aspect in this phrase
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // No sentiment is expressed regarding fairness in assessment in this review
#     },
#     "Experience": {
#         "Aspect Terms": ["interest enough"],
#         "Extracted Phrase": "Now I am interested enough in that subject",
#         "Polarity": "Positive"
#     },
#     "Behavior": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // No behavior aspect mentioned or sentiment expressed in this review
#     }
# }
# ```
# Checkpoint saved after 390 rows.
# Checkpoint saved after 400 rows.
# Checkpoint saved after 410 rows.
# Checkpoint saved after 420 rows.
# JSON parsing failed: Expecting ',' delimiter: line 10 column 31 (char 286)
# Raw response: To provide you with the requested output, let me first present a hypothetical review and then analyze it accordingly:
#
# Review Text: "The teacher was very engaging and made complex concepts understandable. However, the course material felt outdated in some areas and I found the assessment process to be somewhat biased."
#
# Now, let's extract aspect-specific information based on the given aspect categories:
#
# ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["teacher", "engaging"],
#         "Extracted Phrase": "The teacher was very engaging",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (No explicit sentiment mentioned)
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": ["assessment process"],
#         "Extracted Phrase": "I found the assessment process to be somewhat biased",
#         "Polarity": "Negative"
#     },
#     "Experience": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (No explicit sentiment mentioned)
#     },
#     "Behavior": {
#         "Aspect Terms": ["teacher"],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (No explicit sentiment mentioned for the behavior aspect)
#     }
# }
# ```
#
# This output shows that the teacher's pedagogy was appreciated, but there were concerns about the fairness of the assessment process. The other aspects, such as knowledge, experience, and behavior, were not explicitly or implicitly mentioned in this review.
# JSON parsing failed: Extra data: line 8 column 1 (char 333)
# Raw response: 1)
# ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["amazing", "truly inspires", "motivates", "dedication", "commitment", "creative approach"],
#     "Extracted Phrase": "You are an amazing teacher who truly inspires and motivates your students. Thank you for going the extra mile to ensure our success.",
#     "Polarity": "Positive"
#   }
# }
# ```
#
# 2)
# ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["appreciate", "dedication", "commitment", "helping us understand challenging concepts", "passion for teaching"],
#     "Extracted Phrase": "I appreciate your dedication and commitment to helping us understand challenging concepts. Your passion for teaching really shines through.",
#     "Polarity": "Positive"
#   }
# }
# ```
#
# 3)
# ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["thank you", "making learning fun", "engaging"],
#     "Extracted Phrase": "Thank you for making learning fun and engaging. Your creative approach to lessons keeps us excited to come to class each day.",
#     "Polarity": "Positive"
#   }
# }
# ```
#
# 4)
# ```json
# {
#   "Knowledge": {
#     "Aspect Terms": ["gift", "explaining complex topics", "easy to understand"],
#     "Extracted Phrase": "You have a gift for explaining complex topics in a way that is easy to understand. Thank you for your patience and clarity.",
#     "Polarity": "Positive"
#   }
# }
# ```
# JSON parsing failed: Extra data: line 8 column 3 (char 329)
# Raw response: 1)
#   ```json
#   {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["inspires", "motivates", "extra mile", "dedication", "commitment"],
#         "Extracted Phrase": "You are an amazing teacher who truly inspires and motivates your students. Thank you for going the extra mile to ensure our success.",
#         "Polarity": "Positive"
#     }
#   }
#   ```
#
#   2)
#   ```json
#   {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["dedication", "commitment", "passion for teaching"],
#         "Extracted Phrase": "I appreciate your dedication and commitment to helping us understand challenging concepts. Your passion for teaching really shines through.",
#         "Polarity": "Positive"
#     }
#   }
#   ```
#
#   3)
#   ```json
#   {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["fun", "engaging", "creative approach"],
#         "Extracted Phrase": "Thank you for making learning fun and engaging. Your creative approach to lessons keeps us excited to come to class each day.",
#         "Polarity": "Positive"
#     }
#   }
#   ```
#
#   4)
#   ```json
#   {
#     "Knowledge": {
#         "Aspect Terms": ["gift for explaining complex topics", "easy to understand"],
#         "Extracted Phrase": "You have a gift for explaining complex topics in a way that is easy to understand. Thank you for your patience and clarity.",
#         "Polarity": "Positive"
#     }
#   }
#   ```
#
#   5) The following review does not explicitly or implicitly mention the aspect categories: Fair in Assessment, Experience, Behavior. Therefore, these aspects should not be included in the output.
#
#   6) "The textbooks provided by you are outdated and not helpful for our learning."
#
#   7) In this case, although 'textbooks' can be related to 'Knowledge', it is more specifically about resource provision rather than pedagogy or teaching methods. Therefore, no aspects should be included in the output.
#
# 8) "I have never seen a teacher so impatient and disorganized."
#
#   9) In this case, both 'impatient' and 'disorganized' are related to the 'Behavior' aspect category. However, since it is not explicitly stated that these behaviors are related to teaching, it would be more appropriate to only include "Behavior" if a clear connection to teaching is established in the review.
#
#   10) "Your lessons are often too long and boring."
#
#     In this case, both 'long' and 'boring' can be related to the 'Teaching Pedagogy' aspect category. However, since it is not explicitly stated that the length and structure of the lessons affect understanding or learning, it would be more appropriate to only include "Teaching Pedagogy" if a clear connection to teaching effectiveness is established in the review.
# Checkpoint saved after 430 rows.
# JSON parsing failed: Extra data: line 27 column 2 (char 1056)
# Raw response: Here's an example of how the output might look like for two teacher reviews, using the predefined aspect categories. Note that 'Aspect Terms' will contain any terms or phrases mentioned explicitly or implicitly related to the aspect category in the review, and 'Extracted Phrase' is a representative sentence from the review containing those terms or phrases.
#
# ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["Interactive", "Lectures", "Engaging"],
#     "Extracted Phrase": "Her interactive lectures are very engaging.",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Aspect Terms": ["Strong foundation", "Comprehensive understanding"],
#     "Extracted Phrase": "The teacher provides a strong foundation for understanding complex concepts.",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": ["Consistent grading", "Unbiased assessments"],
#     "Extracted Phrase": "I appreciate the consistent grading and unbiased assessments.",
#     "Polarity": "Positive"
#   },
#   "Experience": {
#     "Aspect Terms": ["Friendly demeanor", "Approachable"],
#     "Extracted Phrase": "She has a friendly demeanor that makes her very approachable.",
#     "Polarity": "Positive"
#   },
#   "Behavior": {
#     "Aspect Terms": ["Professionalism", "Respectful", "Punctuality"],
#     "Extracted Phrase": "The teacher demonstrates high professionalism, respect, and is always punctual.",
#     "Polarity": "Positive"
#   }
# },
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["Dull", "Boring"],
#     "Extracted Phrase": "The teacher's lectures are dull and boring.",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": ["Subjective grading"],
#     "Extracted Phrase": "There's a lot of subjectivity in the teacher's grading.",
#     "Polarity": "Negative"
#   },
#   "Experience": {
#     "Aspect Terms": ["Rude behavior"],
#     "Extracted Phrase": "The teacher's rude behavior makes it difficult to have a positive learning experience.",
#     "Polarity": "Negative"
#   },
#   "Behavior": {
#     "Aspect Terms": ["Unprofessional", "Lack of punctuality"],
#     "Extracted Phrase": "The teacher often arrives late and displays unprofessional behavior.",
#     "Polarity": "Negative"
#   }
# }
# ```
# Checkpoint saved after 440 rows.
# JSON parsing failed: Expecting ',' delimiter: line 15 column 31 (char 490)
# Raw response: To analyze the provided teacher review, let's break it down based on the predefined aspect categories. For clarity and ease of understanding, I will provide a detailed breakdown for each category. In a real-world scenario, you would use automated tools or code to perform this analysis at scale.
#
# Review:
# ```bash
# Overall good teacher. The pedagogy is great, always keeps students engaged, very interactive and makes concepts clear. Knowledgeable in the subject matter. However, sometimes can be a bit stern when dealing with minor issues which might not seem fair to some students.
# ```
#
# Output:
# ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["pedagogy", "interactive"],
#         "Extracted Phrase": "always keeps students engaged, very interactive",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["knowledgeable"],
#         "Extracted Phrase": "knowledgeable in the subject matter",
#         "Polarity": "Positive"
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": ["fair"],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (since no sentiment was expressed, only the term "fair" is mentioned)
#     },
#     "Experience": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "" (since the aspect is not explicitly or implicitly mentioned in the review)
#     },
#     "Behavior": {
#         "Aspect Terms": ["stern"],
#         "Extracted Phrase": "can be a bit stern when dealing with minor issues",
#         "Polarity": "Negative" (based on the word "strict" or "sever" that suggests the sentiment is negative)
#     }
# }
# ```
# Checkpoint saved after 450 rows.
# Checkpoint saved after 460 rows.
# Checkpoint saved after 470 rows.
# Checkpoint saved after 480 rows.
# JSON parsing failed: Expecting ',' delimiter: line 11 column 2 (char 334)
# Raw response: ```json
# {
#   "Behavior": {
#       "Aspect Terms": ["friendly", "nice"],
#       "Extracted Phrase": "teacher is friendly during class, such a nice person",
#       "Polarity": "Positive"
#   },
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["interactive"],
#       "Extracted Phrase": "we use to have interactive class",
#       "Polarity": "Positive"
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 10 column 33 (char 244)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["VIP"],
#       "Extracted Phrase": "VIP teacher",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       "Aspect Terms": ["aa"],
#       "Extracted Phrase": "aa",
#       "Polarity": "Unspecified" (since no sentiment polarity is expressed towards the knowledge aspect in this phrase)
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral" (since the review does not provide any information about the fairness of assessment)
#   },
#   "Experience": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral" (since the review does not provide any information about the experience aspect)
#   },
#   "Behavior": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral" (since the review does not provide any information about the behavior aspect)
#   }
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 166)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["cooperative"],
#     "Extracted Phrase": "very very cooperative",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     // Aspect not mentioned, so no output for this category.
#   },
#   "Fair in Assessment": {
#     // Aspect not mentioned, so no output for this category.
#   },
#   "Experience": {
#     // Aspect not mentioned, so no output for this category.
#   },
#   "Behavior": {
#     // Aspect not explicitly or implicitly mentioned, so no output for this category.
#   }
# }
# ```
# Checkpoint saved after 490 rows.
# Checkpoint saved after 500 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 7 (char 173)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["Great"],
#       "Extracted Phrase": "Great Teaching Methodology",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // No aspect mentioned, so do not include it in the output.
#   },
#   "Fair in Assessment": {
#       // No aspect mentioned, so do not include it in the output.
#   },
#   "Experience": {
#       // No aspect mentioned, so do not include it in the output.
#   },
#   "Behavior": {
#       // No aspect mentioned, so do not include it in the output.
#   }
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 15 column 31 (char 633)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["sadae Kary", "mitha dildar alam Sabh"],
#         "Extracted Phrase": "sadae Kary mathy sindh sukar (easy to understand teaching method)",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["Sain ji tareef Kary sagha"],
#         "Extracted Phrase": "Sain ji tareef Kary sagha (praises Sain's knowledge extensively)",
#         "Polarity": "Positive"
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": ["law sain jhara teacher Hugan"],
#         "Extracted Phrase": "law sain jhara teacher Hugan (fair assessments)",
#         "Polarity": "Neutral" // Since there's no clear positive or negative sentiment expressed, assuming neutral.
#     },
#     "Experience": {
#         "Aspect Terms": ["Allah pak kha dua ahy t asa khe ae endar nasalan s"],
#         "Extracted Phrase": "Allah pak kha dua ahy t asa khe ae endar nasalan s (praying for Sain's long life and health, suggesting a positive experience)",
#         "Polarity": "Positive"
#     },
#     "Behavior": {
#         "Aspect Terms": ["makhy alfaz konhan k t maa sain ji tareef Kary sagha jaitra moo wat alfaz konhan k on wadheek sain ji personalty aa Allah pak kha dua ahy t asa khe ae endar nasalan s"],
#         "Extracted Phrase": "makhy alfaz konhan k t maa sain ji tareef Kary sagha jaitra moo wat alfaz konhan k on wadheek sain ji personalty aa Allah pak kha dua ahy t asa khe ae endar nasalan s (compliments Sain's personality and knowledge extensively, expressing respect)",
#         "Polarity": "Positive"
#     }
# }
# ```
# Checkpoint saved after 510 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 9 (char 429)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["interactive", "relate the topic with real life example", "give examples related to topic", "share past experience"],
#         "Extracted Phrase": "Teacher is very much interactive and tries his best to relate the topic with real life example and also give examples related to topic and share past experience",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         // Not mentioned in the review, so no output for this aspect category
#     },
#     "Fair in Assessment": {
#         // Not mentioned in the review, so no output for this aspect category
#     },
#     "Experience": {
#         // Not mentioned in the review, so no output for this aspect category
#     },
#     "Behavior": {
#         // Not mentioned in the review, so no output for this aspect category
#     }
# }
# ```
# Checkpoint saved after 520 rows.
# Checkpoint saved after 530 rows.
# Checkpoint saved after 540 rows.
# Checkpoint saved after 550 rows.
# Checkpoint saved after 560 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 182)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["methodology"],
#     "Extracted Phrase": "They should work on their methodology",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     // No mention of knowledge in the given review, so this section is empty.
#   },
#   "Fair in Assessment": {
#     // No mention of fairness in assessment in the given review, so this section is empty.
#   },
#   "Experience": {
#     // No mention of experience in the given review, so this section is empty.
#   },
#   "Behavior": {
#     // No mention of behavior in the given review, so this section is empty.
#   }
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 126)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["mam"],
#       "Extracted Phrase": "good",
#       "Polarity": "Positive"
#   },
# }
# ```
# Error at index 1459: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 570 rows.
# Checkpoint saved after 580 rows.
# Checkpoint saved after 590 rows.
# JSON parsing failed: Expecting ',' delimiter: line 10 column 30 (char 277)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["delivery style"],
#       "Extracted Phrase": "should work on the delivery style",
#       "Polarity": "Negative"
#   },
#   "Knowledge": {
#       "Aspect Terms": ["teacher"],
#       "Extracted Phrase": "",
#       "Polarity": "Positive" (implicitly from "Teacher is good at teaching")
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   },
#   "Experience": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   },
#   "Behavior": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Neutral"
#   }
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 5 (char 184)
# Raw response: ```json
#     {
#     "Teaching Pedagogy": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "Less interactive or don't know proper teaching method",
#         "Polarity": "Negative"
#     },
#     }
# ```
# In this example, the review indicates a negative sentiment about the teaching pedagogy since the phrase "less interactive or don't know proper teaching method" suggests that the teacher might not have effective methods for engaging students and teaching the material.
# Checkpoint saved after 600 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 7 (char 168)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["very good"],
#       "Extracted Phrase": "Very good teacher",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // No explicit or implicit mention of knowledge, so no output for this aspect category
#   },
#   "Fair in Assessment": {
#       // No explicit or implicit mention of fairness in assessment, so no output for this aspect category
#   },
#   "Experience": {
#       // No explicit or implicit mention of experience, so no output for this aspect category
#   },
#   "Behavior": {
#       // No explicit or implicit mention of behavior, so no output for this aspect category
#   }
# }
# ```
# Checkpoint saved after 610 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 5 (char 157)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["Good"],
#         "Extracted Phrase": "Good way of teaching",
#         "Polarity": "Positive"
#     },
#     // No other aspects were mentioned in the given review, so no need to include them.
# }
# ```
# Checkpoint saved after 620 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 9 (char 175)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["Good"],
#         "Extracted Phrase": "Good instructor",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         // Not mentioned in the review, so no output for this aspect category
#     },
#     "Fair in Assessment": {
#         // Not mentioned in the review, so no output for this aspect category
#     },
#     "Experience": {
#         // Not mentioned in the review, so no output for this aspect category
#     },
#     "Behavior": {
#         // Not mentioned in the review, so no output for this aspect category
#     }
# }
# ```
# Checkpoint saved after 630 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 2 column 5 (char 6)
# Raw response: To guide you through the process of Aspect-Based Sentiment Analysis (ABSA) using Python, I will provide an example with teacher reviews and the predefined aspect categories mentioned in your request. For this example, I will utilize the TextBlob library for sentiment polarity determination and Natural Language Processing (NLP) for aspect extraction.
#
# First, install TextBlob:
#
# ```bash
# !pip install textblob
# ```
#
# Now let's get started with the Python code below:
#
# ```python
# from textblob import TextBlob
# import re
#
# # Sample teacher review
# review = "The teacher is great, but they need to improve in assessments. They often give too much weight to class participation and not enough to homework."
#
# # Define aspect categories
# aspect_categories = {
#     'Teaching Pedagogy': ['teaching', 'pedagogy', 'method'],
#     'Knowledge': ['knowledge', 'expertise'],
#     'Fair in Assessment': ['assessments', 'grading', 'marks'],
#     'Experience': ['experience', 'years_of_experience'],
#     'Behavior': ['behavior', 'attitude']
# }
#
# # Split the review into words and phrases
# review_words = re.findall(r'\b\w+\b', review)
# aspect_phrases = [phrase.lower() for phrase in re.findall(r"(\b[^\s'\"(),.!?:;]*+\b)", review)]
#
# ...
#     }
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 7 (char 198)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["Cooperative", "Supportive"],
#       "Extracted Phrase": "Very Cooperative and Supportive",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // Not mentioned in the review, so no output for this aspect category.
#   },
#   "Fair in Assessment": {
#       // Not mentioned in the review, so no output for this aspect category.
#   },
#   "Experience": {
#       // Not mentioned in the review, so no output for this aspect category.
#   },
#   "Behavior": {
#       // Not mentioned in the review, so no output for this aspect category.
#   }
# }
# ```
# Checkpoint saved after 900 rows.
# Error at index 2322: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 910 rows.
# Checkpoint saved after 920 rows.
# Checkpoint saved after 930 rows.
# Checkpoint saved after 940 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 13 column 7 (char 320)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["teaching skills"],
#       "Extracted Phrase": "great teaching skills",
#       "Polarity": "Positive"
#   },
#   "Behavior": {
#       "Aspect Terms": ["well-mannered"],
#       "Extracted Phrase": "well-mannered teacher",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // No explicit or implicit aspect term related to Knowledge is mentioned in the review.
#   },
#   "Fair in Assessment": {
#       // No explicit or implicit aspect term related to Fair in Assessment is mentioned in the review.
#   },
#   "Experience": {
#       // No explicit or implicit aspect term related to Experience is mentioned in the review.
#   }
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 10 column 37 (char 459)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["passion", "every lesson", "enthusiasm"],
#         "Extracted Phrase": "The English teacher's passion for literature and language was evident in every lesson. Their enthusiasm",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["Shakespeare", "poetry", "grammar"],
#         "Extracted Phrase": "learning Shakespeare, poetry, and grammar",
#         "Polarity": "Not Specified" (as the sentiment is not expressed in this phrase)
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (as the aspect was not mentioned in the review)
#     },
#     "Experience": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Not Specified" (as the sentiment is not expressed in this phrase)
#     },
#     "Behavior": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (as the aspect was not mentioned in the review)
#     }
# }
# ```
# Checkpoint saved after 950 rows.
# JSON parsing failed: Expecting ',' delimiter: line 20 column 38 (char 759)
# Raw response: Here is an example of how you might analyze a teacher review using your specified aspect categories:
#
# ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["creates technique", "learning environment"],
#         "Extracted Phrase": "creates a technique and learning environment to learn with fun and get easily",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["updates knowledge", "skills of students"],
#         "Extracted Phrase": "uses websites, YouTube, and other platforms to update the knowledge and skills of students",
#         "Polarity": "Positive"
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral"
#     },
#     "Experience": {
#         "Aspect Terms": ["experience"],
#         "Extracted Phrase": "experience",
#         "Polarity": "Not Determined" (Since sentiment polarity cannot be determined without additional context)
#     },
#     "Behavior": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" (Since sentiment polarity cannot be determined without additional context)
#     }
# }
# ```
#
# In this example, the review does not explicitly mention the aspects of 'Fair in Assessment', 'Experience', and 'Behavior'. Therefore, those aspects are not included in the output. The aspect terms and extracted phrases are identified from the given review, and the sentiment polarity is determined based on the positive language used to describe the teaching pedagogy and knowledge aspects.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 137)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["good"],
#       "Extracted Phrase": "a good teacher",
#       "Polarity": "Positive"
#   },
# }
# ```
# Checkpoint saved after 960 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 1 (char 141)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["teaching method"],
#       "Extracted Phrase": "amazing",
#       "Polarity": "Positive"
#   },
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 10 column 29 (char 268)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["Good", "teacher"],
#       "Extracted Phrase": "good teacher",
#       "Polarity": "Positive"
#   },
#   "Behavior": {
#       "Aspect Terms": ["attractive"],
#       "Extracted Phrase": "attractive",
#       "Polarity": "Neutral" // Assuming "attractive" is not explicitly negative or positive in the context of teacher behavior
#   },
#   "Knowledge": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "" // As no information about knowledge is provided in the review
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "" // As no information about fairness in assessment is provided in the review
#   },
#   "Experience": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "" // As no information about experience is provided in the review
#   }
# }
# ```
# Checkpoint saved after 970 rows.
# Checkpoint saved after 980 rows.
# Checkpoint saved after 990 rows.
# JSON parsing failed: Expecting value: line 5 column 19 (char 124)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["he"],
#       "Extracted Phrase": "all subject teacher",
#       "Polarity": Neutral
#   },
#   "Knowledge": {
#       "Aspect Terms": ["he"],
#       "Extracted Phrase": "good in it",
#       "Polarity": Positive
#   },
#   "Fair in Assessment": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": Neutral
#   },
#   "Experience": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": Neutral
#   },
#   "Behavior": {
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": Neutral
#   }
# }
# ```
# Checkpoint saved after 1000 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 12 column 3 (char 638)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["acumen", "passion", "course knowledge", "class environment", "used case studies", "articles"],
#       "Extracted Phrase": "His acumen and passion always remained prominent when it came to the course knowledge and class environment. He used case studies and articles to address the course.",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       "Aspect Terms": ["course knowledge", "up-to date statistics in the course"],
#       "Extracted Phrase": "His used case studies and articles to address the course and up-to date statistics in the course.",
#       "Polarity": "Positive"
#   },
#   // Other aspects not mentioned in the review, so they are not included in the output.
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 7 (char 167)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["Amazing"],
#       "Extracted Phrase": "Amazing instructor",
#       "Polarity": "Positive"
#   },
#   "Knowledge": {
#       // Not mentioned in the review, so no output for this aspect category
#   },
#   "Fair in Assessment": {
#       // Not mentioned in the review, so no output for this aspect category
#   },
#   "Experience": {
#       // Not mentioned in the review, so no output for this aspect category
#   },
#   "Behavior": {
#       // Not explicitly mentioned in the review, but 'Amazing' can imply good behavior. However, it is generally safer to label as Neutral unless more context suggests otherwise.
#       "Aspect Terms": [],
#       "Extracted Phrase": "",
#       "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 1010 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 148)
# Raw response: ```json
# {
# "Teaching Pedagogy": {
#     "Aspect Terms": ["Great"],
#     "Extracted Phrase": "great professor",
#     "Polarity": "Positive"
# },
# "Knowledge": {
#     // Not mentioned in the review, so not included in the output.
# },
# "Fair in Assessment": {
#     // Not mentioned in the review, so not included in the output.
# },
# "Experience": {
#     // Not mentioned in the review, so not included in the output.
# },
# "Behavior": {
#     // Not explicitly mentioned, but "professor" could imply behavior. However, without more context, it's better to be conservative and not include it in the output.
# }
# }
# ```
# Checkpoint saved after 1020 rows.
# Checkpoint saved after 1030 rows.
# Checkpoint saved after 1040 rows.
# JSON parsing failed: Expecting ',' delimiter: line 10 column 27 (char 267)
# Raw response: ```json
# {
#   "Knowledge": {
#     "Aspect Terms": ["informative"],
#     "Extracted Phrase": "provides informative knowledge",
#     "Polarity": "Positive"
#   },
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["pedagogy"],
#     "Extracted Phrase": "pedagogy",
#     "Polarity": "Neutral" // Assuming no sentiment is expressed about the pedagogy
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral" // As there's no mention of assessment fairness
#   },
#   "Experience": {
#     "Aspect Terms": ["experience"],
#     "Extracted Phrase": "experience",
#     "Polarity": "Neutral" // Assuming no sentiment is expressed about the experience
#   },
#   "Behavior": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral" // No mention of teacher's behavior in this review
# }
# ```
# Checkpoint saved after 1050 rows.
# Checkpoint saved after 1060 rows.
# JSON parsing failed: Expecting ',' delimiter: line 20 column 27 (char 709)
# Raw response: Here is an example of how the output might look like, based on a review:
#
# ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["Interactive lectures", "Clear explanations"],
#     "Extracted Phrase": "The professor delivers interactive and clear lectures.",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Aspect Terms": ["Deep understanding of the subject matter"],
#     "Extracted Phrase": "This teacher has a deep understanding of the subject matter.",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": ["Fair grading", "Unbiased assessments"],
#     "Extracted Phrase": "The professor provides fair and unbiased assessments.",
#     "Polarity": "Positive"
#   },
#   "Experience": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral" // This aspect was not explicitly mentioned in the review, so we cannot determine its polarity.
#   },
#   "Behavior": {
#     "Aspect Terms": ["Professional demeanor", "Respectful interactions"],
#     "Extracted Phrase": "The professor maintains a professional demeanor and interacts respectfully with students.",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 1070 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 149)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["Good"],
#     "Extracted Phrase": "Good Mentor",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     // Not mentioned in the review, so no output for this category.
#   },
#   "Fair in Assessment": {
#     // Not mentioned in the review, so no output for this category.
#   },
#   "Experience": {
#     // Not mentioned in the review, so no output for this category.
#   },
#   "Behavior": {
#     // Not explicitly or implicitly mentioned in the review, so no output for this category.
#   }
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 10 column 31 (char 248)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "Good",
#         "Polarity": "Positive"
#     },
#     "Knowledge": {
#         "Aspect Terms": ["course"],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // Since the term 'good' doesn't provide specific information about the teacher's knowledge, it is classified as Neutral.
#     },
#     "Fair in Assessment": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // No information provided to make a sentiment polarity determination about the fairness of assessment.
#     },
#     "Experience": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "course",
#         "Polarity": "Positive" // Since 'good' is associated with the course, it can be inferred that the overall experience with the course was positive.
#     },
#     "Behavior": {
#         "Aspect Terms": [],
#         "Extracted Phrase": "",
#         "Polarity": "Neutral" // No information provided to make a sentiment polarity determination about the teacher's behavior.
#     }
# }
# ```
# JSON parsing failed: Expecting ',' delimiter: line 20 column 28 (char 446)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Aspect Terms": ["Excellent"],
#     "Extracted Phrase": "Excellent teacher",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Experience": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Positive" (Assumed as the review is positive overall)
#   },
#   "Behavior": {
#     "Aspect Terms": [],
#     "Extracted Phrase": "",
#     "Polarity": "Neutral" (Assumed as no behavior issues are explicitly mentioned in the given review)
# }
# ```
# Checkpoint saved after 1080 rows.
# Checkpoint saved after 1090 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 5 (char 221)
# Raw response: ```json
# {
#     "Teaching Pedagogy": {
#         "Aspect Terms": ["cooperative", "supportive", "well prepared"],
#         "Extracted Phrase": "very cooperative, supportive and well prepared",
#         "Polarity": "Positive"
#     },
#     // other aspects if mentioned in the review
# }
# ```
# Checkpoint saved after 1100 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 7 column 3 (char 133)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#       "Aspect Terms": ["Learned"],
#       "Extracted Phrase": "a lot",
#       "Polarity": "Positive"
#   },
#   // If no other aspect is mentioned, the rest of the object will be empty.
#   "Knowledge": {},
#   "Fair in Assessment": {},
#   "Experience": {},
#   "Behavior": {}
# }
# ```
# JSON parsing failed: Expecting property name enclosed in double quotes: line 8 column 5 (char 174)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Aspect Terms": ["Always well prepared"],
#     "Extracted Phrase": "Always well prepared",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     // No explicit or implicit mention of 'Knowledge' in the review, thus not included in the output.
#   },
#   "Fair in Assessment": {
#     // No explicit or implicit mention of 'Fair in Assessment' in the review, thus not included in the output.
#   },
#   "Experience": {
#     // No explicit or implicit mention of 'Experience' in the review, thus not included in the output.
#   },
#   "Behavior": {
#     // No explicit or implicit mention of 'Behavior' in the review, thus not included in the output.
#   }
# }
# ```
# Checkpoint saved after 1107 rows.

# %%
# # Add a 'Class' column
# df = pd.read_csv("Datasets/dummyFeedbackdata_nimra.csv")
# df['Class'] = None

# # Group by teacher and subject
# grouped = df.groupby(['FacultyName', 'Course'])

# # Assign class names
# for (teacher, subject), group in grouped:
#     num_records = len(group)
#     num_classes = (num_records + 29) // 30  # Calculate the number of classes (30 students per class)
#     class_names = [f"Class {i+1}" for i in range(num_classes)]  # Generate class names

#     # Assign class names to each record
#     class_assignments = []
#     for i, record in enumerate(group.index):
#         class_assignments.append(class_names[i // 30])  # Assign class based on record index

#     df.loc[group.index, 'Class'] = class_assignments

# # Save the updated DataFrame
# df.to_csv("Datasets/dummyFeedbackdataWithclasses.csv", index=False)

# %% [markdown]
# ### Qwen

# %%
df = pd.read_csv("Datasets/dummyFeedbackdataWithclasses.csv")
model_name = 'qwen2.5-coder:3b'  # Replace with your model name
for count, idx in enumerate(indices_to_process, start=1):
    feedback = df.at[idx, 'Comments']
    try:
        result_json = ask_ollama(feedback, system_prompt, 'qwen2.5-coder:3b')
        df.at[idx, "llm_response"] = result_json  # Save raw LLM response
        
        result_dict = parse_json_safe(result_json)

        if result_dict:
            for aspect in aspects:
                if aspect in result_dict:
                    df.at[idx, f"{aspect}_terms"] = result_dict[aspect].get("Extracted Phrase", "")
                    df.at[idx, f"{aspect}_polarity"] = result_dict[aspect].get("Polarity", "")
    except Exception as e:
        print(f"Error at index {idx}: {e}")
        continue

    if count % batch_size == 0 or count == len(indices_to_process):
        df.loc[indices_to_process].to_csv("Datasets/checkpoint_feedback_Qwen2.csv", index=False)
        print(f"Checkpoint saved after {count} rows.")
# Out:
# Error at index 48: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 202)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Very good teacher",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# Checkpoint saved after 10 rows.
# Checkpoint saved after 20 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 215)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "being there in your consulting hours",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 188)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "very good",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 30 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 200)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "lab pdfs for practice",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 183)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "good",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 40 rows.
# Checkpoint saved after 50 rows.
# Checkpoint saved after 60 rows.
# Error at index 188: 'NoneType' object has no attribute 'get'
# Error at index 193: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 70 rows.
# Error at index 196: 'NoneType' object has no attribute 'get'
# Error at index 203: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 80 rows.
# Checkpoint saved after 90 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 194)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "very supportive",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 100 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 217)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "build up my interest in a creative way",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 110 rows.
# Error at index 299: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 130 rows.
# Error at index 343: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 140 rows.
# Error at index 368: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 238)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "He is not a good teacher",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "he wasted a booming subject",
#     "Polarity": "Negative"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "he has no experience of Data Science",
#     "Polarity": "Negative"
#   },
#   "Behavior": {
#     "Extracted Phrase": "i suggest to my University",
#     "Polarity": "Neutral"
#   }
# }
# ```
# Error at index 409: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 160 rows.
# JSON parsing failed: Expecting value: line 1 column 1 (char 0)
# Raw response: Remarks:
#
# Teaching Pedagogy: Good teaching methods were used.
#
# Knowledge: The teacher was knowledgeable and could explain complex topics clearly.
#
# Fair in Assessment: Fair assessments were given to all students without discrimination.
#
# Experience: The overall experience was positive, with the student feeling well-supported by the teacher.
#
# Behavior: The teacher's behavior was professional and respectful towards both students and the teaching assistants.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 230)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "safa yaar mana ustaad wara hafaal ee na ths..",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "hrr galh ty kawar kando hyo jeko parhaendo hyo panr khe b khbr kon pawandi huys ta parhaya cha tho..",
#     "Polarity": "Positive"
#   },
#   "Behavior": {
#     "Extracted Phrase": "beehr kadah b in master khe data science jo course na dino wanje ta bahr thendo",
#     "Polarity": "Positive"
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 215)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "need a little student interaction",
#     "Polarity": "Neutral"
#   },
#   "Knowledge": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
# "Experience": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
# "Behavior": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   }
# }
# ```
# Checkpoint saved after 170 rows.
# Checkpoint saved after 180 rows.
# Checkpoint saved after 190 rows.
# Checkpoint saved after 200 rows.
# Checkpoint saved after 210 rows.
# JSON parsing failed: Expecting ',' delimiter: line 12 column 27 (char 280)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "very good and knowledgeable",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "islam",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment": {
#     "Extracted Phrase": "fair",
#     "Polarity": "Neutral" // Not mentioned
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": "" // Not mentioned
#   },
#   "Behavior": {
#     "Extracted Phrase": "motivating",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 220 rows.
# Checkpoint saved after 230 rows.
# Checkpoint saved after 240 rows.
# Checkpoint saved after 250 rows.
# Error at index 659: 'NoneType' object has no attribute 'get'
# Error at index 669: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 188)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "motivated",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "best",
#     "Polarity": "Positive"
#   },
#   "Behavior": {
#     "Extracted Phrase": "best the best the best",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 260 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 187)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "mid-term",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# ...
# }
# ```
# Checkpoint saved after 270 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 192)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "like a robots",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Error at index 730: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 280 rows.
# Error at index 735: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 290 rows.
# Error at index 790: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 300 rows.
# Checkpoint saved after 310 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 199)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "best way of teaching",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "cooperative",
#     "Polarity": "Positive"
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 325)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "his humble, understanding, and leniency create a warm and welcoming classroom",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "his wealth of knowledge is seamlessly woven into every lesson",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "his approachability and willingness to adapt to students' needs",
#     "Polarity": "Positive"
#   }
# }
# Checkpoint saved after 320 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 229)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "his way of teaching",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "deliverd their lectures",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 330 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 194)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "way of teaching",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 203)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "The way He teaches",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# ```
# Checkpoint saved after 340 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 14 column 1 (char 246)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
# ...
# }
# Checkpoint saved after 350 rows.
# Checkpoint saved after 360 rows.
# Error at index 939: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 370 rows.
# Checkpoint saved after 380 rows.
# Checkpoint saved after 390 rows.
# Checkpoint saved after 400 rows.
# Error at index 1040: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 410 rows.
# Error at index 1072: 'NoneType' object has no attribute 'get'
# Error at index 1073: 'NoneType' object has no attribute 'get'
# Error at index 1076: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 420 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 396)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Your creative approach to lessons keeps us excited to come to class each day.",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "You are an amazing teacher who truly inspires and motivates your students. Thank you for going the extra mile to ensure our success.",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "Your dedication and commitment to helping us understand challenging concepts. Your passion for teaching really shines through.",
#     "Polarity": "Positive"
#   },
#   "Experience": {
#     "Extracted Phrase": "You have a gift for explaining complex topics in a way that is easy to understand. Thank you for your patience and clarity.",
#     "Polarity": "Positive"
#   },
#   "Behavior": {
#     "Extracted Phrase": "Your dedication and commitment to helping us understand challenging concepts. Your passion for teaching really shines through.",
#     "Polarity": "Positive"
#   }
# }
# ```
# Error at index 1104: 'NoneType' object has no attribute 'get'
# Error at index 1106: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 430 rows.
# Error at index 1122: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 440 rows.
# JSON parsing failed: Expecting property name enclosed in double quotes: line 6 column 1 (char 117)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "forget the boundaries of class",
#     "Polarity": "Negative"
#   },
# }
# ```
# Checkpoint saved after 450 rows.
# Checkpoint saved after 460 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 208)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "so beautiful so elegant",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# ```
# Checkpoint saved after 470 rows.
# Error at index 1237: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 480 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 202)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "amazing teaching skills",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 229)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "his efforts in nurturing a love for learning",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# ```
# Checkpoint saved after 490 rows.
# Checkpoint saved after 500 rows.
# Checkpoint saved after 510 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 301)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "very much interactive, relates topic with real life example, gives examples related to topic, shares past experience",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "shares past experience",
#     "Polarity": "Positive"
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 184)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "great",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 520 rows.
# Error at index 1330: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 220)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "he always tries new way to teach students",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "very kind and helping",
#     "Polarity": "Positive"
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 183)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
# ...
# }
# ```
# Checkpoint saved after 530 rows.
# Checkpoint saved after 540 rows.
# Checkpoint saved after 550 rows.
# Checkpoint saved after 560 rows.
# Checkpoint saved after 570 rows.
# Error at index 1473: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 217)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "always concerned to course and student",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 210)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "her teaching methodology is not",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 580 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 205)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "always stay positive",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# ```
# Checkpoint saved after 590 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 193)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Great Teacher!",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Error at index 1547: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 600 rows.
# Error at index 1593: 'NoneType' object has no attribute 'get'
# Error at index 1600: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 620 rows.
# Checkpoint saved after 630 rows.
# Checkpoint saved after 640 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 201)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "PUTTING HIS BEST",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "COULD NOT REACH AT THE APPROACH OF STUDENTS INTELLIGENCE",
#     "Polarity": "Negative"
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# ```
# Checkpoint saved after 650 rows.
# Error at index 1751: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 660 rows.
# Checkpoint saved after 670 rows.
# Error at index 1767: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 680 rows.
# Checkpoint saved after 690 rows.
# Error at index 1824: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 267)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Sir Irfan Younus Mughal",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "His knowledge and ability of reading the mind of students",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "Sir's natural power of experience",
#     "Polarity": "Positive"
#   },
#   "Behavior": {
#     "Extracted Phrase": "Reads the student's mind and eliminates laziness and non serious attitude",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 700 rows.
# Checkpoint saved after 710 rows.
# Checkpoint saved after 720 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 215)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Excellent Teacher",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "out of date",
#     "Polarity": "Negative"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 211)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "enforced for self reading",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": "Neutral"
#   }
# }
# ```
# Checkpoint saved after 730 rows.
# Error at index 1911: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 740 rows.
# Checkpoint saved after 750 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 186)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "sarcasm",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 760 rows.
# Checkpoint saved after 770 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 209)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "cooperative and supportive",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
# "Experience": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
# "Behavior": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   }
# }
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 200)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "sometimes strict",
#     "Polarity": "Neutral"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   }
# }
# ```
# Checkpoint saved after 780 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 197)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "All the engage us.",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 213)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Overall 10/10",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "Overall 10/10",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "Overall 10/10",
#     "Polarity": "Positive"
#   },
#   "Experience": {
#     "Extracted Phrase": "Overall 10/10",
#     "Polarity": "Positive"
#   },
#   "Behavior": {
#     "Extracted Phrase": "Overall 10/10",
#     "Polarity": "Positive"
#   }
# }
# Checkpoint saved after 790 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 195)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "the best teacher",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 800 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 270)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "teaches with very fast pace",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "Sir shows little understanding regarding student concerns",
#     "Polarity": "Neutral"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "students concerns are not heard",
#     "Polarity": "Negative"
#   }
# }
# ```
# Checkpoint saved after 810 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 231)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "turning a boring subject into a very interesting one",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Error at index 2096: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 221)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "thought that we already knew but we didn't",
#     "Polarity": "Negative"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 820 rows.
# Error at index 2126: 'NoneType' object has no attribute 'get'
# Error at index 2130: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 830 rows.
# Checkpoint saved after 840 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 216)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "excellent way of conveying course",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
#   "Experience": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
#   "Behavior": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   }
# }
# ```
# JSON parsing failed: Expecting value: line 1 column 1 (char 0)
# Raw response: Understood. Please provide the review text so I can analyze it and extract the relevant information based on the specified aspect categories.
# Checkpoint saved after 850 rows.
# Error at index 2203: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 860 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 191)
# Raw response: {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "give respect",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "encourage",
#     "Polarity": "Positive"
#   }
# }
# Checkpoint saved after 870 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 201)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "always relax the class",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 880 rows.
# Error at index 2298: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 212)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "collaborative with other students",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "discriminated me against class participations",
#     "Polarity": "Negative"
#   }
# }
# ```
# Checkpoint saved after 900 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 196)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Knowledge": {
#     "Extracted Phrase": "full of knowledge",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# ...
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 246)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "encouraging students to come forward and having class participation",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# "Experience": {
#     "Extracted Phrase": "nice time with him through out the semester",
#     "Polarity": "Positive"
#   },
# "Behavior": {
#     "Extracted Phrase": "focusing on encouraging students to come forward and having class participation",
#     "Polarity": "Positive"
#   }
# }
# ```
# Checkpoint saved after 910 rows.
# Error at index 2380: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 920 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 199)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "teacher is very good",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 930 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 201)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "teach English language",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# ...
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 204)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "good in every perspective",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Error at index 2436: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 940 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 206)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "SIR TEACHES VERY WELL",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Experience": {
#     "Extracted Phrase": "...",
#     "Polarity": "..."
#   },
#   "Behavior": {
#     "Extracted Phrase": "SIR IS VERY DOWN TO EARTH",
#     "Polarity": "Positive"
#   }
# }
# ```
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 201)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "teach with amazing way",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
# ...
# }
# ```
# Checkpoint saved after 950 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 190)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "really good",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 960 rows.
# Checkpoint saved after 970 rows.
# Checkpoint saved after 980 rows.
# Checkpoint saved after 990 rows.
# Checkpoint saved after 1000 rows.
# Checkpoint saved after 1010 rows.
# Error at index 2611: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 247)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "diverse portfolio of knowledge",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "diverse portfolio of knowledge",
#     "Polarity": "Positive"
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   },
# "Experience": {
#     "Extracted Phrase": "on field experience",
#     "Polarity": "Positive"
#   },
# "Behavior": {
#     "Extracted Phrase": null,
#     "Polarity": null
#   }
# }
# ```
# Checkpoint saved after 1020 rows.
# Error at index 2654: 'NoneType' object has no attribute 'get'
# Error at index 2703: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 183)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "good",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 1040 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 223)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "very sincere towards his teaching profession",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Error at index 2772: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 1050 rows.
# Error at index 2789: 'NoneType' object has no attribute 'get'
# Checkpoint saved after 1060 rows.
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 206)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "method of teaching was good",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Error at index 2801: 'NoneType' object has no attribute 'get'
# Error at index 2802: 'NoneType' object has no attribute 'get'
# JSON parsing failed: Invalid control character at: line 10 column 22 (char 188)
# Raw response: ```json
# {
#   "Teaching Pedagogy": {
#     "Extracted Phrase": "Inspiring",
#     "Polarity": "Positive"
#   },
#   "Knowledge": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Fair in Assessment
# ": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Experience": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   },
#   "Behavior": {
#     "Extracted Phrase": "",
#     "Polarity": ""
#   }
# }
# ```
# Checkpoint saved after 1080 rows.
# Checkpoint saved after 1090 rows.
# Checkpoint saved after 1100 rows.
# Checkpoint saved after 1107 rows.
